# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
df = pd.read_csv('Dataset/hindi_songs.csv', encoding="utf-8")
print(df[365:370])
# Out:
#      srNo             Song_Name                Singer              Genre  \
# 365   366  Baarish (Atif Aslam)            Atif Aslam  BollywoodRomantic
# 366   367          Akkad Bakkad  Badshah, Neha Kakkar     BollywoodDance
# 367   368  Tum Ho Toh Lagta Hai                 Shaan  BollywoodRomantic
# 368   369    Kya Khoob Lagti Ho                   NaN     BollywoodDance
# 369   370    Kya Khoob Lagti Ho       Kanchan, Mukesh  BollywoodRomantic
#
#                Movie  Rating
# 365  Half Girlfriend  9.3/10
# 366         Sanam Re  9.1/10
# 367     Dil Juunglee  9.7/10
# 368        Dharmatma  8.6/10
# 369        Dharmatma  8.6/10

# %%
API_KEY = "AIzaSyAnTJPB4AzcVx_RVrz_DlcOMoChsS_1cmE"
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %%
def get_youtube_link(song_name):
    try:
        request = youtube.search().list(
            part="snippet",
            maxResults=1,
            q=song_name
        )
        
        response = request.execute()
        video_id = response['items'][0]['id']['videoId']
        return f"https://www.youtube.com/watch?v={video_id}"
    except Exception as e:
        print(f"Error fetching YouTube link for {song_name}: {e}")
        return None

# %%
df.isnull().sum()
df["Singer"]=df["Singer"].fillna('ND')
df["Movie"]=df["Movie"].fillna("ND")
df.isnull().sum()
# Out:
# srNo         0
# Song_Name    0
# Singer       0
# Genre        0
# Movie        0
# Rating       0
# dtype: int64

# %%
youtube_links = []

for i in range(len(df)):
    print(i)
    query=df["Song_Name"][i] + " by " + df["Singer"][i]
    # print(s ,": ", get_youtube_link(s))
    try:
        yt_link=get_youtube_link(query)
        youtube_links.append(yt_link)
    except(e):
        print(e)

df["Youtube_link"]=youtube_links
print(len(df["Youtube_link"]))
print(df["Youtube_link"])
df.to_csv("Dataset/hindi_songs.csv", index=False)
# Out:
# Error fetching YouTube link for Aankh Marey by Kumar Sanu, Mika Singh, Neha Kakkar: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=1&q=Aankh+Marey+by+Kumar+Sanu%2C+Mika+Singh%2C+Neha+Kakkar&key=AIzaSyAnTJPB4AzcVx_RVrz_DlcOMoChsS_1cmE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ...
